# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

# %%
import sys 
sys.path.append('../pandaslab/functions')
sys.path.append('../pandaslab/processing')

# %%
mimic = pd.read_csv('../data/mimic/mimic.csv')
mimic = mimic.set_index(['SUBJECT_ID', 'HADM_ID'])

# %%
mimic.head()

# %%
from utilities import types
types = types(mimic)

# %%
from sklearn.model_selection import train_test_split

data = mimic.dropna(axis=0)
X = data.drop('DIED', axis=1)
y = data['DIED']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2)

# %% [markdown]
# ### Normalization

# %%
pd.set_option('chained_assignment',None)

# %%
from normalization import standard
normalized_X = standard(X, type='Numerical')

# %%
normalized_X.head()
# Out:
#                    INSURANCE LANGUAGE       RELIGION MARITAL_STATUS  \
# SUBJECT_ID HADM_ID
# 357        174486    Private     ENGL  NOT SPECIFIED        MARRIED
# 359        144265   Self Pay     VIET       BUDDHIST        MARRIED
# 43         146828    Private     ENGL  NOT SPECIFIED        MARRIED
# 44         181750   Medicare     ENGL       CATHOLIC        MARRIED
# 64         172056   Medicaid     ENGL          OTHER         SINGLE
#
#                                  ETHNICITY GENDER  AGE       LOS  HR_MIN_DAY1  \
# SUBJECT_ID HADM_ID
# 357        174486                    WHITE      M   62  2.498235    -0.915510
# 359        144265    UNKNOWN/NOT SPECIFIED      M   48 -0.266886    -0.121508
# 43         146828                    WHITE      M   32 -0.064291     0.407826
# 44         181750    UNKNOWN/NOT SPECIFIED      M   80 -0.141784    -0.187675
# 64         172056   BLACK/AFRICAN AMERICAN      F   26 -0.439319     1.069493
#
# ...

# %% [markdown]
# ### Encoding
#
# #### Categorical variables

# %%
from encoding import likelihood
encoded_X = likelihood(normalized_X, type='Categorical')

# %%
encoded_X.head()
# Out:
#                    INSURANCE   LANGUAGE  RELIGION MARITAL_STATUS ETHNICITY  \
# SUBJECT_ID HADM_ID
# 357        174486   0.407731  0.0127918  0.280084      -0.102153 -0.194977
# 359        144265    1.61478    0.32811  0.252475      -0.102153 -0.310876
# 43         146828   0.407731  0.0127918  0.280084      -0.102153 -0.194977
# 44         181750  -0.568439  0.0127918 -0.200086      -0.102153 -0.310876
# 64         172056    1.06344  0.0127918  0.420411       0.578097   1.28836
#
#                    GENDER       AGE       LOS  HR_MIN_DAY1  HR_MAX_DAY1  \
# SUBJECT_ID HADM_ID
# 357        174486       M  0.151475  2.498235    -0.915510    -1.698557
# 359        144265       M  0.995046 -0.266886    -0.121508    -0.796335
# 43         146828       M  1.776322 -0.064291     0.407826     0.105887
# 44         181750       M -1.258486 -0.141784    -0.187675    -0.996829
# 64         172056       F  0.764633 -0.439319     1.069493     0.506874
#
# ...

# %% [markdown]
# #### Binary variables

# %%
from encoding import label
encoded_X = label(encoded_X, type='Binary')

# %%
encoded_X.head()
# Out:
#                    INSURANCE   LANGUAGE  RELIGION MARITAL_STATUS ETHNICITY  \
# SUBJECT_ID HADM_ID
# 357        174486   0.407731  0.0127918  0.280084      -0.102153 -0.194977
# 359        144265    1.61478    0.32811  0.252475      -0.102153 -0.310876
# 43         146828   0.407731  0.0127918  0.280084      -0.102153 -0.194977
# 44         181750  -0.568439  0.0127918 -0.200086      -0.102153 -0.310876
# 64         172056    1.06344  0.0127918  0.420411       0.578097   1.28836
#
#                    GENDER       AGE       LOS  HR_MIN_DAY1  HR_MAX_DAY1  \
# SUBJECT_ID HADM_ID
# 357        174486       0  0.151475  2.498235    -0.915510    -1.698557
# 359        144265       0  0.995046 -0.266886    -0.121508    -0.796335
# 43         146828       0  1.776322 -0.064291     0.407826     0.105887
# 44         181750       0 -1.258486 -0.141784    -0.187675    -0.996829
# 64         172056       1  0.764633 -0.439319     1.069493     0.506874
#
# ...

# %% [markdown]
# ### Label Encoding

# %%
from encoding import label
encoded_X2 = label(normalized_X, type='Binary_Categorical')

# %%
encoded_X2.head()
# Out:
#                    INSURANCE LANGUAGE RELIGION MARITAL_STATUS ETHNICITY  \
# SUBJECT_ID HADM_ID
# 357        174486          0        0        0              0         0
# 359        144265          1        1        1              0         1
# 43         146828          0        0        0              0         0
# 44         181750          2        0        2              0         1
# 64         172056          3        0        3              1         2
#
#                    GENDER  AGE       LOS  HR_MIN_DAY1  HR_MAX_DAY1 ...   V81  \
# SUBJECT_ID HADM_ID                                                 ...
# 357        174486       0   62  2.498235    -0.915510    -1.698557 ...     0
# 359        144265       0   48 -0.266886    -0.121508    -0.796335 ...     0
# 43         146828       0   32 -0.064291     0.407826     0.105887 ...     0
# 44         181750       0   80 -0.141784    -0.187675    -0.996829 ...     0
# ...

# %%
from encoding import one_hot
encoded_X3 = one_hot(normalized_X, type='Categorical')
encoded_X3 = label(encoded_X3, type='Binary')

# %%
encoded_X3.head()
# Out:
#                    GENDER       LOS  HR_MIN_DAY1  HR_MAX_DAY1  HR_MEAN_DAY1  \
# SUBJECT_ID HADM_ID
# 357        174486       0  2.498235    -0.915510    -1.698557     -1.340782
# 359        144265       0 -0.266886    -0.121508    -0.796335     -0.319270
# 43         146828       0 -0.064291     0.407826     0.105887      0.136666
# 44         181750       0 -0.141784    -0.187675    -0.996829     -0.681095
# 64         172056       1 -0.439319     1.069493     0.506874      0.928173
#
#                     SYS_BP_MIN_DAY1  SYS_BP_MAX_DAY1  SYS_BP_MEAN_DAY1  \
# SUBJECT_ID HADM_ID
# 357        174486         -1.624393         0.910527          0.086255
# 359        144265         -0.568377        -1.537163         -1.133110
# 43         146828          1.543655        -0.102310          0.957891
# 44         181750          1.250317        -0.271117          0.343384
# 64         172056          0.604974        -1.368357         -0.554172
#
# ...
